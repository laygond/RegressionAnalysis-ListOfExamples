# %% [markdown]
# # Estimating House Prices
#
# In this demo

# %% [markdown]
# ## Load CSV File with Panda
#
# We first load the packages as usual.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Next, we load a CSV file containing the data as a panda dataframe and inspect the first 6 samples. When loading the data, note that we specify that the data comes with no header and instead create field names of our own. Also in case there are no valid values 'n/a', 'nan', 'null', etc then set to '?'

# %%
names =[
    'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM',
    'AGE',  'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'PRICE'
]

df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data',
                 header=None,delim_whitespace=True,names=names,na_values='?')

print(df.head(6))
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# 5  0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2
# 5     18.7  394.12   5.21   28.7

# %% [markdown]
# ## Manipulate the Data
#
# Let's manipulate the Data to get familiar with it

# %%
numSamples, numAttributes = df.shape
print('numSamples = ', numSamples, ' numAttributes = ', numAttributes)

# print(df.columns)
# print(df.index)
# print(df.values)

y = np.array(df['PRICE'])

yMean = np.mean(y)
numAbove40 = np.sum(y>40)
percentAbove40 = numAbove40/len(y)*100
print('The mean house price is ',yMean, ' thousands of dollars.')
print('Only ', percentAbove40, 'percent are above $40k.')
# Out:
# numSamples =  506  numAttributes =  14
# The mean house price is  22.532806324110677  thousands of dollars.
# Only  6.126482213438735 percent are above $40k.

# %% [markdown]
# ## Visualize the Data
#
# Visualize the data to get a better understanding of it.

# %%
x = np.array(df['RM'])

plt.plot(x,y,'o')
plt.xlabel('RM')
plt.ylabel('PRICE')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Fitting a Simple Linear Model
#
# Given vectors of data points (x,y), performs a fit for the linear model:
#        yhat = beta0 + beta1*x,

# %%
#-----------FITTING A SIMPLE LINEAR MODEL---------
def fit_linear(x,y):
    """
    Given vectors of data points (x,y), performs a fit for the linear model:
       yhat = beta0 + beta1*x, 
    The function returns beta0, beta1 and R_2, where R_2 is the coefficient of determination.
    """

    xm = np.mean(x)
    ym = np.mean(y)
    syy = np.mean((y-ym)**2)
    syx = np.mean((y-ym)*(x-xm))
    sxx = np.mean((x-xm)**2)
    stdy = np.sqrt(syy)
    stdx = np.sqrt(sxx)
    beta1 = syx/sxx
    beta0 = ym - beta1*xm
    ryx = syx/(stdx*stdy)
    R_2 = ryx*ryx

    return beta0, beta1, R_2

beta0,beta1,R_2 = fit_linear(x,y)
print('beta0 = ', beta0)
print('beta1 = ', beta1)
print('R_2 = ', R_2)

# Predicted regression line
xp = np.array([4,9])        #Pick two points to plot line
yp = beta1*xp + beta0
plt.plot(x,y,'o',xp,yp,'-',linewidth=3)  # Plot the regression line on same figure
plt.show();
# Out:
# beta0 =  -34.67062077643857
# beta1 =  9.10210898118031
# R_2 =  0.483525455991334

# %% [markdown]
# ## Compute Coefficients of Determination

# %%
def Calc_R_2(x,y):
    """
    Given vectors of data points (x,y), performs a fit for the linear model:
       yhat = beta0 + beta1*x, 
    The function returns beta0, beta1 and R_2, where R_2 is the coefficient of determination.
    """

    xm = np.mean(x)
    ym = np.mean(y)
    syy = np.mean((y-ym)**2)
    syx = np.mean((y-ym)*(x-xm))
    sxx = np.mean((x-xm)**2)
    stdy = np.sqrt(syy)
    stdx = np.sqrt(sxx)
    ryx = syx/(stdx*stdy)
    R_2 = ryx*ryx

    return R_2

R_2_Values = np.zeros(len(names)-1)             #Empty array to store R_2
for i in range(len(names)-1):
    x_for_det = np.array(df[names[i]])
    R_2_Values[i] = Calc_R_2(x_for_det,y)

npnames = np.array(names[0:len(names)-1])       #transform dictionary into np array
table = np.column_stack((npnames,R_2_Values))   #create matrix style

print('TABLE OF COEFFICIENTS OF DETERMINATION')
print(pd.DataFrame(table))                      #print panda table structure
# Out:
# TABLE OF COEFFICIENTS OF DETERMINATION
#           0                     1
# 0      CRIM     0.150780469049757
# 1        ZN   0.12992084489428934
# 2     INDUS   0.23399003044447492
# 3      CHAS  0.030716129708774794
# 4       NOX    0.1826030425016989
# 5        RM     0.483525455991334
# 6       AGE    0.1420947440778043
# 7       DIS   0.06246437212178246
# 8       RAD    0.1456385799123251
# 9       TAX   0.21952592104421897
# 10  PTRATIO    0.2578473180092229
# 11        B   0.11119611824636265
# 12    LSTAT    0.5441462975864796
